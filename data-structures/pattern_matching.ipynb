# %%
def handle_command(self, message):
 match message:
  case ['BEEPER', frequency, times]: # matches a list of three, first element being 'BEEPER'
    self.beep(times, frequency)
  case ['NECK', angle]: # matches a list of two, first element being 'NECK'
    self.rotate_neck(angle)
  case ['LED', ident, intensity]:
    self.leds[ident].set_brightness(ident, intensity)
  case ['LED', ident, red, green, blue]:
    self.leds[ident].set_color(ident, red, green, blue)
  case _:
    raise InvalidCommand(message)

# %%
handle_command(['NECK', 45])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-30d96a91fbd5> in <cell line: 0>()
# ----> 1 handle_command(['NECK', 45])
#
# TypeError: handle_command() missing 1 required positional argument: 'message'
