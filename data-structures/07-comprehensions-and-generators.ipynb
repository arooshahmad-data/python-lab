# %% [markdown]
# The following below implementation is from the Book **Fluent Python Clear, Concise, and Effective Programming by Luciano Ramalho**

# %%
# Generator Expressions
symbols = '$¢£¥€¤'

tuple(ord(symbol) for symbol in symbols) # Generate a tuple using generator expression
# Out:
# (36, 162, 163, 165, 8364, 164)

# %%
import array

array.array('I',(ord(symbol) for symbol in symbols)) # I tells here the data type of data to store. it ,
                                                     # means unsigned integer here
# Out:
# array('I', [36, 162, 163, 165, 8364, 164])
